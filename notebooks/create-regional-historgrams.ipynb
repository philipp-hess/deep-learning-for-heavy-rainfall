# %%
# %load_ext autoreload
# %autoreload 2
# %cd /home/hess/projects/dynamical-state-index

# %%
import matplotlib.pyplot as plt
from src.plot_utils import PlotHistograms

# %%
path_dict = {'dnn_weighted': '/path/to/model_output.npy',
             'dnn_mssim': '/path/to/model_output.npy',
             'dnn': '/path/to/model_output.npy',
             'qm': '/path/to/model_output.npy',
             'linear': '/path/to/model_output.npy'}

histograms = PlotHistograms(path='')
histograms.model_file_names = path_dict
histograms.load_data()
histograms.mask_data()

# %%
plt.figure(figsize=(8,5))
plt.title('Tropics-land')
fname = f'figure_name.pdf'
histograms.plot(fname=fname)
